# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
from IPython.display import display,HTML
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Leo mi archivo.csv
Covid = pd.read_csv("220827COVID19MEXICO.csv")
#Filtro por filas
Covid= Covid.iloc[0:100000,: ]
Covid
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0              27/08/2022      1a4a8d       1      12          23     2
# 1              27/08/2022      01e27d       2       9          25     2
# 2              27/08/2022      13cf10       2       9           9     1
# 3              27/08/2022      13c92b       2      12           9     1
# 4              27/08/2022      04af5f       2      12           9     1
# ...                   ...         ...     ...     ...         ...   ...
# 99995          27/08/2022      47548a       2      12           9     1
# 99996          27/08/2022      5c2773       2      12           9     2
# 99997          27/08/2022      aceb1f       2       4          28     2
# 99998          27/08/2022      db2a23       2       4           9     1
# 99999          27/08/2022      a88222       2       4           9     1
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# ...

# %%
valores_nulos=Covid.isnull().sum()
valores_nulos
# Out:
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             0
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               0
# OTRO_CASO                0
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# TOMA_MUESTRA_ANTIGENO    0
# ...
