# %%
#Importo librerias
import pandas as pd
import numpy as np

# %%
#Leo mi archivo.csv
Alumnos = pd.read_csv("MiClaseAnalitica.csv") #, index_col=0
Alumnos

# %%
#Verifico el tipo de dato de mi elemento alumnos
type(Alumnos)

# %%
#verificamos la ubicación de los elemenmtos nulos del dataframe
Dataframe_nulos= Alumnos.isnull()
Dataframe_nulos

# %%
#Obtenemos la cuenta de los elementos nulos del dataframe por COLUMNA
Cuenta_Nulos= Alumnos.isnull().sum()
Cuenta_Nulos

# %%
#Obtenemos la cuenta de los elementos nulos del dataframe por FILA
Cuenta_Nulos= Alumnos.isnull().sum(axis=1)
Cuenta_Nulos

# %%
#Obtenemos la cuenta de los elementos nulos del dataframe completo
Cuenta_Total_Nulos= Alumnos.isnull().sum().sum()
Cuenta_Total_Nulos

# %%
#Verificamos cuantos datos hay de cada valor
frecuencia= Alumnos['actividad'].value_counts()
frecuencia
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\alfre\OneDrive\Escritorio\Analítica de Datos\Repositorio PROYECTO 1\proyecto1\4_Valores_nulos.ipynb Celda 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive/Escritorio/Anal%C3%ADtica%20de%20Datos/Repositorio%20PROYECTO%201/proyecto1/4_Valores_nulos.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> #Verificamos cuantos datos hay de cada valor
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive/Escritorio/Anal%C3%ADtica%20de%20Datos/Repositorio%20PROYECTO%201/proyecto1/4_Valores_nulos.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> frecuencia= Alumnos['actividad'].value_counts()
#       <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive/Escritorio/Anal%C3%ADtica%20de%20Datos/Repositorio%20PROYECTO%201/proyecto1/4_Valores_nulos.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> frecuencia
#
# NameError: name 'Alumnos' is not defined

# %%
#Verificamos valores nulos por columna
nulos= Alumnos['actividad'].value_counts(dropna=False)
nulos

# %%
#Eliminamos filas con nulos
Alumnos.dropna()

# %%
#Eliminamos columnas con nulos
Alumnos.dropna(1)

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
#Filtro por columnas
Actividad_total=Alumnos.iloc[ : , [6]]
Actividad_total.fillna(4)

# %%
#Sustituir valores nulos por un string en  concreto 
#Filtro por columnas
Actividad_total=Alumnos.iloc[ : , [6]]
Actividad_total.fillna("8 de ago en 14:14")

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
Actividad_total=Alumnos.iloc[ : , [6]]
Actividad_total.fillna(method="ffill")

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
Actividad_total=Alumnos.iloc[ : , [6]]
Actividad_total.fillna(method="bfill")

###esta es una prueba de sincronización
