# %% [markdown]
# <a href="https://colab.research.google.com/github/freddy-7/proyecto1/blob/main/introducci%C3%B3n%20pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-39c7dd2f-fe78-4881-b31b-c10967a309ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39c7dd2f-fe78-4881-b31b-c10967a309ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fileee.csv to fileee.csv

# %%
#Importar archivo desde un dispositivo local
import pandas as pd 
import io 
  
df = pd.read_csv(io.BytesIO(uploaded['fileee.csv'])) 
print(df)


#Importar archivo desde Github

#url = 'copied_raw_github_link'
#df = pd.read_csv(url)
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0        2005          1           Nacional  Hombres
# 1        2005          1           Nacional  Mujeres
# 2        2005          1     Aguascalientes  Hombres
# 3        2005          1     Aguascalientes  Mujeres
# 4        2005          1    Baja California  Hombres
# ...       ...        ...                ...      ...
# 4549     2022          1           Veracruz  Mujeres
# 4550     2022          1            Yucat n  Hombres
# 4551     2022          1            Yucat n  Mujeres
# 4552     2022          1          Zacatecas  Hombres
# 4553     2022          1          Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                            4384907          26597801
# 1                                            2690296          14843275
# 2                                              56407            246177
# ...

# %%
df
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0        2005          1           Nacional  Hombres
# 1        2005          1           Nacional  Mujeres
# 2        2005          1     Aguascalientes  Hombres
# 3        2005          1     Aguascalientes  Mujeres
# 4        2005          1    Baja California  Hombres
# ...       ...        ...                ...      ...
# 4549     2022          1           Veracruz  Mujeres
# 4550     2022          1            Yucat n  Hombres
# 4551     2022          1            Yucat n  Mujeres
# 4552     2022          1          Zacatecas  Hombres
# 4553     2022          1          Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                            4384907          26597801
# 1                                            2690296          14843275
# 2                                              56407            246177
# ...

# %%
#filtro básico 
E=df[df["Sexo"] == "Hombres"]
E
# Out:
#       Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 0        2005          1             Nacional  Hombres
# 2        2005          1       Aguascalientes  Hombres
# 4        2005          1      Baja California  Hombres
# 6        2005          1  Baja California Sur  Hombres
# 8        2005          1             Campeche  Hombres
# ...       ...        ...                  ...      ...
# 4544     2022          1           Tamaulipas  Hombres
# 4546     2022          1             Tlaxcala  Hombres
# 4548     2022          1             Veracruz  Hombres
# 4550     2022          1              Yucat n  Hombres
# 4552     2022          1            Zacatecas  Hombres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                            4384907          26597801
# 2                                              56407            246177
# 4                                             167651            768989
# ...

# %%
#Convertir archivo filtrado a CSV
E.to_csv("E_CSV.csv")
# Out:
#       Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 0        2005          1             Nacional  Hombres
# 2        2005          1       Aguascalientes  Hombres
# 4        2005          1      Baja California  Hombres
# 6        2005          1  Baja California Sur  Hombres
# 8        2005          1             Campeche  Hombres
# ...       ...        ...                  ...      ...
# 4544     2022          1           Tamaulipas  Hombres
# 4546     2022          1             Tlaxcala  Hombres
# 4548     2022          1             Veracruz  Hombres
# 4550     2022          1              Yucat n  Hombres
# 4552     2022          1            Zacatecas  Hombres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                            4384907          26597801
# 2                                              56407            246177
# 4                                             167651            768989
# ...

# %%
from google.colab import files 
  
  
files.download("E_CSV.csv")
